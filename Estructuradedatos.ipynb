# %% [markdown]
# <img src="img/Recurso-26.png" width="200">
#
# ## TERCER MODULO - Estructuras de datos, +Pandas
#
# ![logo](img/python_logo.png)
#
# *Santiago Carrasco*

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### Operaciones en pandas

# %% [markdown]
# #### Búsqueda

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  5  5  0
# 1  1  2  0

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())
display(frame.isin([4])) #devuelve una mask con valores true si el elemento es 4
print(frame.isin([4]).values)
type(frame.isin([4]).values) # pandas es una capa alrededor de numpy
# Out:
# 0
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# [[False False False]
#  [False False False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())
display(mask)
# Out:
# 3
#        A     B      C
# 0   True  True  False
# 1  False  True  False

# %% [markdown]
# #### Ordenación

# %%
from random import shuffle
rand_matrix = np.random.randint(20,size=(5,4))
indices = list(range(5))
shuffle(indices) # mezcla indices
frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C   B
# 4   4   4  16   6
# 2  13   6  15  14
# 3   3  16   1  16
# 1  12   2  10  10
# 0  15   0   2   2

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C   B
# 4   4   4  16   6
# 3   3  16   1  16
# 2  13   6  15  14
# 1  12   2  10  10
# 0  15   0   2   2
#     D   A   C   B
# 4   4   4  16   6
# 2  13   6  15  14
# 3   3  16   1  16
# 1  12   2  10  10
# 0  15   0   2   2

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 4   4  16   6   4
# 2  13  15  14   6
# 3   3   1  16  16
# 1  12  10  10   2
# 0  15   2   2   0

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 4   4  16   6   4
# 2  13  15  14   6
# 3   3   1  16  16
# 1  12  10  10   2
# 0  15   2   2   0

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C   B
# 0  15   0   2   2
# 1  12   2  10  10
# 4   4   4  16   6
# 2  13   6  15  14
# 3   3  16   1  16

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#     A   C   B   D
# 4   4  16   6   4
# 2   6  15  14  13
# 3  16   1  16   3
# 1   2  10  10  12
# 0   0   2   2  15

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C   B
# 3   3  16   1  16
# 2  13   6  15  14
# 4   4   4  16   6
# 1  12   2  10  10
# 0  15   0   2   2

# %% [markdown]
# #### Ranking

# %% [markdown]
# * Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C   B
# 3   3  16   1  16
# 2  13   6  15  14
# 4   4   4  16   6
# 1  12   2  10  10
# 0  15   0   2   2

# %%
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 3  2.0  4.0  1.0  4.0
# 2  2.0  1.0  4.0  3.0
# 4  2.0  2.0  4.0  3.0
# 1  4.0  1.0  3.0  3.0
# 0  4.0  1.0  3.0  3.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 16
# 15
# 10
# 2
# 1

# %% [markdown]
# #### Operaciones

# %% [markdown]
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  23  51  20  37
# 1  44  54  94   3
# 2  10   2  34  69
# 3  18  18  35  78
#     0   1   2   3
# 0  62  81  24  13
# 1  87   9  49  79
# 2  78  25  13  45
# 3  32  19  97  46

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0   85  132   44   50
# 1  131   63  143   82
# 2   88   27   47  114
# 3   50   37  132  124

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0  39  30   4 -24
# 1  43 -45 -45  76
# 2  68  23 -21 -24
# 3  14   1  62 -32

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0  23  51  20  37
# 1  44  54  94   3
# 2  10   2  34  69
# 3  18  18  35  78
#     0   1   2
# 0  75  85  56
# 1  55  73  83
# 2  69  88  66
#       0      1      2   3
# 0  98.0  136.0   76.0 NaN
# 1  99.0  127.0  177.0 NaN
# 2  79.0   90.0  100.0 NaN
# 3   NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#       0      1      2     3
# 0  98.0  136.0   76.0  37.0
# 1  99.0  127.0  177.0   3.0
# 2  79.0   90.0  100.0  69.0
# 3  18.0   18.0   35.0  78.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
display(frameD)
frameA - frameD

# %% [markdown]
# Operaciones entre Series y DataFrame

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)
display(df.iloc[0])
display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  2  1  5  9
# 1  2  3  7  0
# 2  6  6  0  0
# A    2
# B    1
# C    5
# D    9
# Name: 0, dtype: int32
# pandas.core.series.Series
#    A  B  C  D
# 0  0  0  0  0
# 1  0  2  2 -9
# 2  4  5 -5 -9
#    A  B  C  D
# 0  0  0  0  0
# 1  0  2  2 -9
# 2  4  5 -5 -9
#    A  B  C  D
# 0  0 -1  3  7
# 1  0  1  5 -2
# 2  0  0 -6 -6

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables

# %%
import pandas as pd

datos = [
# UNARIO
["Unario", "abs", "Valor absoluto de cada elemento"],
["", "sqrt", "Raíz cuadrada de cada elemento"],
["", "exp", "e^x, siendo x cada elemento"],
["", "log, log10, log2", "Logaritmos en distintas bases de cada elemento"],
["", "sign", "Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo)"],
["", "ceil", "Redondea cada elemento por arriba"],
["", "floor", "Redondea cada elemento por abajo"],
["", "isnan", "Retorna si cada elemento es Nan"],
["", "cos, sin, tan", "Operaciones trigonométricas en cada elemento"],
["", "arccos, arcsin, arctan", "Inversas de operaciones trigonométricas en cada elemento"],

# BINARIO
["Binario", "add", "Suma de dos arrays"],
["", "substract", "Resta de dos arrays"],
["", "multiply", "Multiplicación de dos arrays"],
["", "divide", "División de dos arrays"],
["", "maximum, minimum", "Retorna el valor máximo/mínimo de cada pareja de elementos"],
]

tabla = pd.DataFrame(datos, columns=["Tipo", "Operación", "Descripción"])

display(tabla)
# Out:
#        Tipo               Operación  \
# 0    Unario                     abs
# 1                              sqrt
# 2                               exp
# 3                  log, log10, log2
# 4                              sign
# 5                              ceil
# 6                             floor
# 7                             isnan
# 8                     cos, sin, tan
# 9            arccos, arcsin, arctan
# 10  Binario                     add
# 11                        substract
# 12                         multiply
# 13                           divide
# 14                 maximum, minimum
#
#                                           Descripción
# 0                     Valor absoluto de cada elemento
# 1                      Raíz cuadrada de cada elemento
# 2                         e^x, siendo x cada elemento
# 3      Logaritmos en distintas bases de cada elemento
# 4   Retorna el signo de cada elemento (-1 para neg...
# 5                   Redondea cada elemento por arriba
# 6                    Redondea cada elemento por abajo
# 7                     Retorna si cada elemento es Nan
# 8        Operaciones trigonométricas en cada elemento
# 9   Inversas de operaciones trigonométricas en cad...
# 10                                 Suma de dos arrays
# 11                                Resta de dos arrays
# 12                       Multiplicación de dos arrays
# 13                             División de dos arrays
# 14  Retorna el valor máximo/mínimo de cada pareja ...

# %%
import pandas as pd

datos = [
["", "equal, not_equal", "Retorna la comparación (igual o no igual) de cada pareja de elementos"],
["", "greater, greater_equal, less, less_equal", "Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos"],
]

tabla = pd.DataFrame(datos, columns=["Tipo", "Operación", "Descripción"])

display(tabla)
# Out:
#   Tipo                                 Operación  \
# 0                               equal, not_equal
# 1       greater, greater_equal, less, less_equal
#
#                                          Descripción
# 0  Retorna la comparación (igual o no igual) de c...
# 1  Retorna la comparación (>, >=, <, <= respectiv...

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por colu
# Out:
#    A  B  C  D
# 0  6  1  4  5
# 1  1  5  9  9
# 2  3  9  8  0
# 0    5
# 1    8
# 2    9
# dtype: int64

# %%
def max_min(x):
    return x.max() - x.min()
print(frame.apply(max_min, axis = 0)) # diferencia por columna
# Out:
# A    5
# B    8
# C    5
# D    9
# dtype: int64

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  4  1  7  4
# 1  9  8  7  9
# 2  0  5  1  9
# 0    6
# 1    2
# 2    9
# dtype: int64

# %% [markdown]
# #### Estadística descriptiva

# %% [markdown]
# * Análisis preliminar de los datos
# * Para Series y DataFrame

# %%
import pandas as pd

datos = [
["count", "Número de valores no NaN"],
["describe", "Conjunto de estadísticas sumarias"],
["min, max", "Valores mínimo y máximo"],
["argmin, argmax", "Índices posicionales del valor mínimo y máximo"],
["idxmin, idxmax", "Índices semánticos del valor mínimo y máximo"],
["sum", "Suma de los elementos"],
["mean", "Media de los elementos"],
["median", "Mediana de los elementos"],
["mad", "Desviación absoluta media del valor medio"],
["var", "Varianza de los elementos"],
["std", "Desviación estándar de los elementos"],
["cumsum", "Suma acumulada de los elementos"],
]

tabla = pd.DataFrame(datos, columns=["Operación", "Descripción"])

display(tabla)
# Out:
#          Operación                                     Descripción
# 0            count                        Número de valores no NaN
# 1         describe               Conjunto de estadísticas sumarias
# 2         min, max                         Valores mínimo y máximo
# 3   argmin, argmax  Índices posicionales del valor mínimo y máximo
# 4   idxmin, idxmax    Índices semánticos del valor mínimo y máximo
# 5              sum                           Suma de los elementos
# 6             mean                          Media de los elementos
# 7           median                        Mediana de los elementos
# 8              mad       Desviación absoluta media del valor medio
# 9              var                       Varianza de los elementos
# 10             std            Desviación estándar de los elementos
# 11          cumsum                 Suma acumulada de los elementos

# %%
import pandas as pd

datos = [
["diff", "Diferencia aritmética de los elementos"],
]

tabla = pd.DataFrame(datos, columns=["Operación", "Descripción"])

display(tabla)
# Out:
#   Operación                             Descripción
# 0      diff  Diferencia aritmética de los elementos

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel","Carlos"], 
"edad" : [34,30,25,28],
"puntos" : [98,12,98,np.nan], 
"genero" : ["F", "F", "M", "M"] }

frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe())  # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    30    12.0      F
# 2  Manuel    25    98.0      M
# 3  Carlos    28     NaN      M
#             edad     puntos
# count   4.000000   3.000000
# mean   29.250000  69.333333
# std     3.774917  49.652123
# min    25.000000  12.000000
# 25%    27.250000  55.000000
# 50%    29.000000  98.000000
# 75%    31.000000  98.000000
# max    34.000000  98.000000

# %%
# operadores básicos
print(frame.sum())
display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
# nombre    MarisaLauraManuelCarlos
# edad                          117
# puntos                      208.0
# genero                       FFMM
# dtype: object
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    30    12.0      F
# 2  Manuel    25    98.0      M
# 3  Carlos    28     NaN      M
# 0    132.0
# 1     42.0
# 2    123.0
# 3     28.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      29.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    64   110.0     FF
# 2        MarisaLauraManuel    89   208.0    FFM
# 3  MarisaLauraManuelCarlos   117     NaN   FFMM

# %%
frame.count(axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
print(frame['edad'].std())
# Out:
# 3.774917217635375

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
# frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())
display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    25    98.0      M

# %%
frame["ranking"] = frame["puntos"].rank(method='max')

# %%
display(frame)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    30    12.0      F      1.0
# 2  Manuel    25    98.0      M      3.0
# 3  Carlos    28     NaN      M      NaN

# %% [markdown]
# ### Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    30    12.0      F      1.0
# 2  Manuel    25    98.0      M      3.0
# 3  Carlos    28     NaN      M      NaN
#         nombre  edad  puntos  ranking
# genero
# F            2     2       2        2
# M            2     2       1        1

# %%
# si es Nan descarta la fila
df = frame.groupby('puntos').count()
display(df)
# Out:
#         nombre  edad  genero  ranking
# puntos
# 12.0         1     1       1        1
# 98.0         2     2       2        2

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos  ranking
# genero
# F       32.0    55.0      2.0
# M       26.5    98.0      3.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos  ranking
# genero
# F       Marisa    34    98.0      3.0
# M       Manuel    28    98.0      3.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada 
def media(x):
    return x["edad"].mean() > 30
display(frame)
frame.groupby('genero').filter(media)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    30    12.0      F      1.0
# 2  Manuel    25    98.0      M      3.0
# 3  Carlos    28     NaN      M      NaN
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    30    12.0      F      1.0

# %% [markdown]
# ### Correlaciones

# %% [markdown]
# pandas incluye métodos para analizar correlaciones
# * Relación matemática entre dos variables (-1 negativamente relacionadas, 1
# * positivamente relacionadas, 0 sin relación)
# * obj.corr(obj2) --> medida de correlación entre los datos de ambos objetos
# * https://blogs.oracle.com/ai-and-datascience/post/introduction-to-correlation

# %% [markdown]
# ### Ejemplo Fuel efficiency

# %% [markdown]
# * https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd

path = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

mpg_data = pd.read_csv(path, sep='\s+', header=None,
                       names=['mpg', 'cilindros', 'desplazamiento', 'potencia',
                              'peso', 'aceleracion', 'año', 'origen', 'nombre'],
                       na_values='?', engine='c')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 54   35.0          4            72.0      69.0  1613.0         18.0   71
# 163  18.0          6           225.0      95.0  3785.0         19.0   75
# 386  25.0          6           181.0     110.0  2945.0         16.4   82
# 263  17.7          6           231.0     165.0  3445.0         13.4   78
# 363  22.4          6           231.0     110.0  3415.0         15.8   81
#
#      origen                           nombre
# 54        3                      datsun 1200
# 163       1                    plymouth fury
# 386       1            buick century limited
# 263       1  buick regal sport coupe (turbo)
# 363       1                    buick century

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
# np.float64(-0.8317409332443351)

# %%
mpg_data['peso'].corr(mpg_data['aceleracion']) # + peso = - aceleracion
# Out:
# np.float64(-0.4174573199403932)

# %% [markdown]
# ### Correlaciones entre todos los valores

# %%
mpg_data.corr(numeric_only=True)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
# año             0.579267  -0.348746       -0.370164 -0.416361 -0.306564
# origen          0.563450  -0.562543       -0.609409 -0.455171 -0.581024
#
#                 aceleracion       año    origen
# mpg                0.420289  0.579267  0.563450
# cilindros         -0.505419 -0.348746 -0.562543
# desplazamiento    -0.543684 -0.370164 -0.609409
# potencia          -0.689196 -0.416361 -0.455171
# peso              -0.417457 -0.306564 -0.581024
# aceleracion        1.000000  0.288137  0.205873
# año                0.288137  1.000000  0.180662
# origen             0.205873  0.180662  1.000000

# %%
#año y origen no parecen correlacionables
#eliminar columnas de la correlacion
corr_data = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
display(corr_data)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        1.000000

# %%
# representación gráfica matplotlib
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# representación gráfica
corr_data.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1)
# Out:
# <style type="text/css">
# #T_79686_row0_col0, #T_79686_row1_col1, #T_79686_row2_col2, #T_79686_row3_col3, #T_79686_row4_col4, #T_79686_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_79686_row0_col1, #T_79686_row0_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_79686_row0_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_79686_row0_col4, #T_79686_row1_col0, #T_79686_row2_col0, #T_79686_row3_col0, #T_79686_row4_col0, #T_79686_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_79686_row0_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_79686_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_79686_row1_col3, #T_79686_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_79686_row1_col4, #T_79686_row2_col3, #T_79686_row3_col2, #T_79686_row4_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_79686_row1_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_79686_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_79686_row2_col4, #T_79686_row4_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_79686_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_79686_row3_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_79686_row3_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_79686_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_79686_row4_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_79686_row5_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_79686_row5_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_79686_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_79686_row5_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_79686">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79686_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_79686_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_79686_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_79686_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_79686_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_79686_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79686_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_79686_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_79686_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_79686_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_79686_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_79686_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_79686_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_79686_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_79686_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_79686_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_79686_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_79686_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_79686_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_79686_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_79686_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_79686_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_79686_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_79686_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_79686_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_79686_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_79686_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_79686_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_79686_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_79686_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_79686_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_79686_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_79686_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_79686_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_79686_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_79686_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_79686_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_79686_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_79686_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_79686_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_79686_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_79686_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_79686_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_79686_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_79686_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_79686_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_79686_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_79686_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlación más negativa
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmin()
# Out:
# mpg                   peso
# cilindros              mpg
# desplazamiento         mpg
# potencia               mpg
# peso                   mpg
# aceleracion       potencia
# dtype: object

# %%
# correlación más positiva
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmax()
# Out:
# mpg                          mpg
# cilindros              cilindros
# desplazamiento    desplazamiento
# potencia                potencia
# peso                        peso
# aceleracion          aceleracion
# dtype: object

# %%
# tabla similar con las correlaciones más positivas (evitar parejas del mismo va
positive_corr = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
np.fill_diagonal(positive_corr.values, 0)
display(positive_corr)
positive_corr.idxmax()
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             0.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   0.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        0.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  0.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  0.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        0.000000
# mpg                  aceleracion
# cilindros         desplazamiento
# desplazamiento         cilindros
# potencia          desplazamiento
# peso              desplazamiento
# aceleracion                  mpg
# dtype: object
