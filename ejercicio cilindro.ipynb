# %% [markdown]
# <img src="img/itq.jpeg" width="200">
# <h2 style="text-align: center;"> Tarea programa cilindro</h2>
#
#
# <img src="img/Python.jpeg" width="500" style="display:block;margin:auto;">
#
# Nombre: *Santiago Carrasco*

# %%
pi = 3.1416
radio = float(input("Ingrese el radio del cilindro: "))
altura = float(input("Ingrese la altura del cilindro: "))
volumen = pi * (radio ** 2) * altura
print(volumen)
# Out:
# Ingrese el radio del cilindro:  5
# Ingrese la altura del cilindro:  10
# 785.3999999999999

# %% [markdown]
# https://github.com/Santi2w/introduccion-a-Python-clase-2/blob/main/ejercicio%20cilindro.ipynb
