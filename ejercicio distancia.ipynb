# %% [markdown]
# <img src="img/itq.jpeg" width="200">
# <h2 style="text-align: center;"> Tarea programa distancia </h2>
#
#
# <img src="img/Python.jpeg" width="500" style="display:block;margin:auto;">
#
# Nombre: *Santiago Carrasco*

# %%
metros = float(input("Ingrese el valor en metros: "))

centimetros = metros * 100
milimetros = metros * 1000
kilometros = metros / 1000

print("-----------------------------------")
print(f"Valor ingresado: {metros} m")
print("-----------------------------------")
print(f"En Centímetros:  {centimetros} cm")
print(f"En Milímetros:   {milimetros} mm")
print(f"En Kilómetros:   {kilometros} km")
print("-----------------------------------")
# Out:
# Ingrese el valor en metros:  120
# -----------------------------------
# Valor ingresado: 120.0 m
# -----------------------------------
# En Centímetros:  12000.0 cm
# En Milímetros:   120000.0 mm
# En Kilómetros:   0.12 km
# -----------------------------------

# %% [markdown]
# https://github.com/Santi2w/introduccion-a-Python-clase-2/blob/main/ejercicio%20distancia.ipynb
